# %%
import sys

sys.path.append("../")

# %%
import pandas as pd

from otodom_offers_scrapper import get_offer_params
from utils import get_creds, load_offers_params_table

# %%
url = (
    "https://www.otodom.pl/pl/oferta/"
    "komfortowe-90m2-plus-125m2-ogrodka-przy-ul-olesin-ID4ke6e"
)

print(url)
# Out:
# https://www.otodom.pl/pl/oferta/komfortowe-90m2-plus-125m2-ogrodka-przy-ul-olesin-ID4ke6e

# %%
get_offer_params(url)
# Out:
# {'price': '799 000 zl',
#  'price_m2': '8 878 zl/m2',
#  'address': 'Warszawa, Bialoleka, ul. Olesinska ',
#  'powierzchnia': '90 m2',
#  'liczba_pokoi': '5',
#  'stan_wykonczenia': 'do wykonczenia',
#  'rynek': 'pierwotny',
#  'typ_ogloszeniodawcy': 'prywatny',
#  'winda': 'nie'}

# %%
creds = get_creds("../database.txt")

# %%
df = load_offers_params_table(creds, date_from = "2023-06-11", limit=10)

# %%
df
# Out:
#             create_timestamp
# 0 2023-06-11 01:20:24.887092  \
# 1 2023-06-11 01:19:12.174290
# 2 2023-06-11 01:19:13.738547
# 3 2023-06-11 01:19:15.254548
# 4 2023-06-11 01:19:16.788690
# 5 2023-06-11 01:19:18.196771
# 6 2023-06-11 01:19:19.706038
# 7 2023-06-11 01:19:21.204346
# 8 2023-06-11 01:19:22.674277
# 9 2023-06-11 01:19:24.161857
#
#                                                   id       price     price_m2
# 0                    mieszkanie-49-m-czeladz-ID4kWjR  259 000 zl  5 286 zl/m2  \
# 1  apartament-3-pokojowy-kompletnie-urzadzony-ID4...  370 650 zl  6 167 zl/m2
# 2  mieszkanie-czeladz-spoldzielcza-bezposrednio-I...  219 000 zl  4 389 zl/m2
# 3           sprzedam-dwupoziomowe-mieszkanie-ID4lEYx  430 000 zl  5 375 zl/m2
# 4     czeladz-mieszkanie-centrum-po-remoncie-ID4l515  258 000 zl  6 453 zl/m2
# 5              sprzedam-przytulne-mieszkanie-ID4hJt1  230 000 zl  4 792 zl/m2
# 6             czeladz-piaski-ul-nowopogonska-ID4lP3L  134 999 zl  3 462 zl/m2
# ...
